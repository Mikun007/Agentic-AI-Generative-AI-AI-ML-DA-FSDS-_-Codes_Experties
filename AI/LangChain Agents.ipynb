# %% [markdown]
# ## How to Use Agents to interact with pandas DataFrame
#
# ## In Langchain, the Agent can access many dataframes at once

# %%
# !pip install langchain watermark openai langchain-experimental tabulate
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [watermark]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
#    -------------------------- ------------- 2/3 [langchain-experimental]
# ...

# %%
# !pip install langchain-openai

# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain_openai import ChatOpenAI

# %%
from langchain.agents import create_agent

# %%
os.environ["OPENAI_API_KEY"] = ""

# %%
model = ChatOpenAI(
    model="gpt-3",
    temperature=0.1,
    max_tokens=1000,
    timeout=30
)

agent = create_agent(model)

# %%
agent

# %%
df = pd.read_csv(r"C:\Users\mikun\Downloads\archive\Titanic-Dataset.csv")

# %%
agent = create_pandas_dataframe_agent()
