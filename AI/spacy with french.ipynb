# %%
import spacy
nlp = spacy.load("fr_core_news_sm")
doc = nlp("Bonjour Bonne après-midi Je m'appelle Mondly e suis ravi de vous rencontrer Comment ça va ")

# %%
# !python -m spacy download fr_core_news_sm

# %%
doc
# Out:
# Bonjour Bonne après-midi Je m'appelle Mondly e suis ravi de vous rencontrer Comment ça va

# %%
for token in doc:
    print(token.text)
# Out:
# Bonjour
# Bonne
# après-midi
# Je
# m'
# appelle
# Mondly
# e
# suis
# ravi
# de
# vous
# rencontrer
# Comment
# ça
# va

# %%
for token in doc:
    print(token.pos_) #part of speach (POS)
# Out:
# PROPN
# ADJ
# NOUN
# PRON
# PRON
# VERB
# PROPN
# AUX
# AUX
# VERB
# ADP
# PRON
# VERB
# ADV
# PRON
# VERB

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# Bonjour PROPN
# Bonne ADJ
# après-midi NOUN
# Je PRON
# m' PRON
# appelle VERB
# Mondly PROPN
# e AUX
# suis AUX
# ravi VERB
# de ADP
# vous PRON
# rencontrer VERB
# Comment ADV
# ça PRON
# va VERB

# %%
for token in doc:
    print(token.text, token.pos_, token.lemma_) # part of speach and lemmatization
# Out:
# Bonjour PROPN Bonjour
# Bonne ADJ bon
# après-midi NOUN après-midi
# Je PRON je
# m' PRON me
# appelle VERB appeler
# Mondly PROPN Mondly
# e AUX e
# suis AUX être
# ravi VERB ravir
# de ADP de
# vous PRON vous
# rencontrer VERB rencontrer
# Comment ADV comment
# ça PRON cela
# va VERB aller

# %%
text = """Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de 
résumé. Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.). Le second est le résumé pertinent pour une 
requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête. Les systèmes de résum
é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement 
en fonction des besoins de l'utilisateur.Un exemple de problème de résumé est le résumé de documents, qui tente de produire 
automatiquement un résumé à partir d'un document donné. Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
ument source, tandis que d'autres peuvent utiliser plusieurs documents sources (par exemple, un ensemble d'articles sur le 
même sujet). Ce problème est appelé résumé multi-documents. Une application connexe est le résumé d'articles d'actualité. I
maginez un système qui rassemble automatiquement des articles d'actualité sur un sujet donné (à partir du Web) et représent
e de manière concise les dernières informations sous forme de résumé.Le résumé d'une collection d'images est un autre exemp
le d'application de résumé automatique. Il consiste à sélectionner un ensemble représentatif d'images parmi un ensemble plu
s large d'images. Dans ce contexte, un résumé est utile pour montrer les images les plus représentatives des résultats dans 
un système d'exploration de collections d'images. La vidéo résumée est un domaine connexe, où le système crée automatiqueme
nt une bande-annonce d'une longue vidéo. Cela trouve également des applications dans les vidéos grand public ou personnelle
s, où l'on peut vouloir passer les actions ennuyeuses ou répétitives. De même, dans les vidéos de surveillance, on souhaite
rait extraire les activités importantes et suspectes, tout en ignorant les images ennuyeuses et redondantes capturées."""

# %%
text
# Out:
# "Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de \nrésumé. Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag\nisse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.). Le second est le résumé pertinent pour une \nrequête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête. Les systèmes de résum\né sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement \nen fonction des besoins de l'utilisateur.Un exemple de problème de résumé est le résumé de documents, qui tente de produire \nautomatiquement un résumé à partir d'un document donné. Parfois, on peut souhaiter générer un résumé à partir d'un seul doc\nument source, tandis que d'autres peuvent utiliser plusieurs documents sources (par exemple, un ensemble d'articles sur 
# ...

# %%
import spacy 
from spacy.lang.fr.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)
stopwords
# Out:
# ['depuis',
#  'dedans',
#  'très',
#  'cinquante',
#  'quelques',
#  'durant',
#  'elle-meme',
#  'aie',
#  'hep',
#  'si',
#  'ne',
#  'puis',
#  'parlent',
#  'aux',
#  'hi',
#  'dehors',
#  'votre',
#  'reste',
#  'précisement',
#  'elles-memes',
#  'auraient',
#  'ses',
#  'plusieurs',
#  'dite',
#  'nous',
#  'tes',
#  'rendre',
#  'ma',
#  'jusque',
#  'ci',
#  'dessous',
#  'derrière',
#  'néanmoins',
#  'après',
#  'votres',
#  'toi',
#  'vôtre',
#  'desquels',
#  'tiens',
#  'egalement',
#  'stop',
#  'quant-à-soi',
#  "quelqu'un",
#  'antérieures',
#  'trente',
#  'restant',
#  'faisant',
#  'tous',
#  'certes',
#  'souvent',
#  'encore',
#  'etre',
#  'plutot',
#  'delà',
#  'selon',
#  'relative',
#  'vingt',
#  'sinon',
#  'vé',
#  'quelles',
#  'de',
#  'plutôt',
#  'celle-ci',
#  'pourquoi',
#  'le',
#  'celui',
#  'spécifique',
#  'tien',
#  'malgré',
#  'faisaient',
#  'avons',
#  'tel',
#  'mêmes',
#  'huit',
#  'à',
#  'duquel',
#  'qui',
#  'son',
#  'désormais',
# ...

# %%
len(stopwords)
# Out:
# 507

# %%
nlp = spacy.load("fr_core_news_sm")

# %%
text
# Out:
# "Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de \nrésumé. Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag\nisse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.). Le second est le résumé pertinent pour une \nrequête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête. Les systèmes de résum\né sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement \nen fonction des besoins de l'utilisateur.Un exemple de problème de résumé est le résumé de documents, qui tente de produire \nautomatiquement un résumé à partir d'un document donné. Parfois, on peut souhaiter générer un résumé à partir d'un seul doc\nument source, tandis que d'autres peuvent utiliser plusieurs documents sources (par exemple, un ensemble d'articles sur 
# ...

# %%
doc = nlp(text)

# %%
doc
# Out:
# Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de
# résumé. Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
# isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.). Le second est le résumé pertinent pour une
# requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête. Les systèmes de résum
# é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement
# en fonction des besoins de l'utilisateur.Un exemple de problème de résumé est le résumé de documents, qui tente de produire
# automatiquement un résumé à partir d'un document donné. Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
# ...

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Il', 'existe', 'essentiellement', 'deux', 'types', 'de', 'tâches', 'de', 'résumé', 'extractif', 'en', 'fonction', 'de', 'ce', 'sur', 'quoi', 'se', 'concentre', 'le', 'programme', 'de', '\n', 'résumé', '.', 'Le', 'premier', 'est', 'le', 'résumé', 'générique', ',', 'qui', 'vise', 'à', 'obtenir', 'un', 'résumé', 'générique', 'ou', 'abstrait', 'de', 'la', 'collection', '(', "qu'", 'il', "s'", 'ag', '\n', 'isse', 'de', 'documents', ',', "d'", 'ensembles', "d'", 'images', ',', 'de', 'vidéos', ',', "d'", 'articles', 'de', 'presse', ',', 'etc.', ')', '.', 'Le', 'second', 'est', 'le', 'résumé', 'pertinent', 'pour', 'une', '\n', 'requête', ',', 'parfois', 'appelé', 'résumé', 'basé', 'sur', 'une', 'requête', ',', 'qui', 'résume', 'des', 'objets', 'spécifiques', 'à', 'une', 'requête', '.', 'Les', 'systèmes', 'de', 'résum', '\n', 'é', 'sont', 'capables', 'de', 'créer', 'à', 'la', 'fois', 'des', 'résumés', 'textuels', 'pertinents', 'pour', 'une', 'requête', 'et', 'des', 'résumés', 'générés', 'au
# ...

# %%
tokens
# Out:
# ['Il',
#  'existe',
#  'essentiellement',
#  'deux',
#  'types',
#  'de',
#  'tâches',
#  'de',
#  'résumé',
#  'extractif',
#  'en',
#  'fonction',
#  'de',
#  'ce',
#  'sur',
#  'quoi',
#  'se',
#  'concentre',
#  'le',
#  'programme',
#  'de',
#  '\n',
#  'résumé',
#  '.',
#  'Le',
#  'premier',
#  'est',
#  'le',
#  'résumé',
#  'générique',
#  ',',
#  'qui',
#  'vise',
#  'à',
#  'obtenir',
#  'un',
#  'résumé',
#  'générique',
#  'ou',
#  'abstrait',
#  'de',
#  'la',
#  'collection',
#  '(',
#  "qu'",
#  'il',
#  "s'",
#  'ag',
#  '\n',
#  'isse',
#  'de',
#  'documents',
#  ',',
#  "d'",
#  'ensembles',
#  "d'",
#  'images',
#  ',',
#  'de',
#  'vidéos',
#  ',',
#  "d'",
#  'articles',
#  'de',
#  'presse',
#  ',',
#  'etc.',
#  ')',
#  '.',
#  'Le',
#  'second',
#  'est',
#  'le',
#  'résumé',
#  'pertinent',
#  'pour',
#  'une',
#  '\n',
#  'requête',
#  ',',
#  'parfois',
#  'appelé',
#  'résumé',
#  'basé',
#  'sur',
#  'une',
#  'requête',
#  ',',
#  'qui',
#  'résume',
# ...

# %%
len(tokens)
# Out:
# 402

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
doc
# Out:
# Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de
# résumé. Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
# isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.). Le second est le résumé pertinent pour une
# requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête. Les systèmes de résum
# é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement
# en fonction des besoins de l'utilisateur.Un exemple de problème de résumé est le résumé de documents, qui tente de produire
# automatiquement un résumé à partir d'un document donné. Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
# ...

# %%
word_frequencies = {}

for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
print(word_frequencies)
# Out:
# {'existe': 1, 'essentiellement': 1, 'types': 1, 'tâches': 1, 'résumé': 16, 'extractif': 1, 'fonction': 2, 'concentre': 1, 'programme': 1, '\n': 16, 'générique': 2, 'vise': 1, 'obtenir': 1, 'abstrait': 1, 'collection': 2, 'ag': 1, 'isse': 1, 'documents': 3, 'ensembles': 1, 'images': 7, 'vidéos': 3, 'articles': 4, 'presse': 1, 'etc.': 1, 'second': 1, 'pertinent': 1, 'requête': 4, 'appelé': 2, 'basé': 1, 'résume': 1, 'objets': 1, 'systèmes': 1, 'résum': 1, 'é': 1, 'capables': 1, 'créer': 1, 'fois': 1, 'résumés': 2, 'textuels': 1, 'pertinents': 1, 'générés': 1, 'automatiquement': 3, 'besoins': 1, 'utilisateur': 1, 'exemple': 2, 'problème': 2, 'produire': 1, 'partir': 3, 'document': 1, 'donné': 2, 'souhaiter': 1, 'générer': 1, 'doc': 1, 'ument': 1, 'source': 1, 'tandis': 1, 'utiliser': 1, 'sources': 1, 'ensemble': 3, 'sujet': 2, 'multi-documents': 1, 'application': 2, 'connexe': 2, 'actualité': 2, 'maginez': 1, 'système': 3, 'rassemble': 1, 'Web': 1, 'représent': 1, 'e': 1, 'manière': 1, 
# ...

# %%
len(word_frequencies)
# Out:
# 119

# %%
word_frequencies
# Out:
# {'existe': 1,
#  'essentiellement': 1,
#  'types': 1,
#  'tâches': 1,
#  'résumé': 16,
#  'extractif': 1,
#  'fonction': 2,
#  'concentre': 1,
#  'programme': 1,
#  '\n': 16,
#  'générique': 2,
#  'vise': 1,
#  'obtenir': 1,
#  'abstrait': 1,
#  'collection': 2,
#  'ag': 1,
#  'isse': 1,
#  'documents': 3,
#  'ensembles': 1,
#  'images': 7,
#  'vidéos': 3,
#  'articles': 4,
#  'presse': 1,
#  'etc.': 1,
#  'second': 1,
#  'pertinent': 1,
#  'requête': 4,
#  'appelé': 2,
#  'basé': 1,
#  'résume': 1,
#  'objets': 1,
#  'systèmes': 1,
#  'résum': 1,
#  'é': 1,
#  'capables': 1,
#  'créer': 1,
#  'fois': 1,
#  'résumés': 2,
#  'textuels': 1,
#  'pertinents': 1,
#  'générés': 1,
#  'automatiquement': 3,
#  'besoins': 1,
#  'utilisateur': 1,
#  'exemple': 2,
#  'problème': 2,
#  'produire': 1,
#  'partir': 3,
#  'document': 1,
#  'donné': 2,
#  'souhaiter': 1,
#  'générer': 1,
#  'doc': 1,
#  'ument': 1,
#  'source': 1,
#  'tandis': 1,
#  'utiliser': 1,
#  'sources': 1,
#  'ensemble': 3,
# ...

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 16

# %%
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency

# %%
word_frequencies
# Out:
# {'existe': 0.0625,
#  'essentiellement': 0.0625,
#  'types': 0.0625,
#  'tâches': 0.0625,
#  'résumé': 1.0,
#  'extractif': 0.0625,
#  'fonction': 0.125,
#  'concentre': 0.0625,
#  'programme': 0.0625,
#  '\n': 1.0,
#  'générique': 0.125,
#  'vise': 0.0625,
#  'obtenir': 0.0625,
#  'abstrait': 0.0625,
#  'collection': 0.125,
#  'ag': 0.0625,
#  'isse': 0.0625,
#  'documents': 0.1875,
#  'ensembles': 0.0625,
#  'images': 0.4375,
#  'vidéos': 0.1875,
#  'articles': 0.25,
#  'presse': 0.0625,
#  'etc.': 0.0625,
#  'second': 0.0625,
#  'pertinent': 0.0625,
#  'requête': 0.25,
#  'appelé': 0.125,
#  'basé': 0.0625,
#  'résume': 0.0625,
#  'objets': 0.0625,
#  'systèmes': 0.0625,
#  'résum': 0.0625,
#  'é': 0.0625,
#  'capables': 0.0625,
#  'créer': 0.0625,
#  'fois': 0.0625,
#  'résumés': 0.125,
#  'textuels': 0.0625,
#  'pertinents': 0.0625,
#  'générés': 0.0625,
#  'automatiquement': 0.1875,
#  'besoins': 0.0625,
#  'utilisateur': 0.0625,
#  'exemple': 0.125,
#  'problème': 0.125,
# ...

# %%
sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# [Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de
#  résumé.,
#  Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
#  isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.).,
#  Le second est le résumé pertinent pour une
#  requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête.,
#  Les systèmes de résum
#  é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement
#  en fonction des besoins de l'utilisateur.,
#  Un exemple de problème de résumé est le résumé de documents, qui tente de produire
#  automatiquement un résumé à partir d'un document donné.,
#  Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
# ...

# %%
len(sentence_tokens)
# Out:
# 15

# %%
sentence_tokens
# Out:
# [Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de
#  résumé.,
#  Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
#  isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.).,
#  Le second est le résumé pertinent pour une
#  requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête.,
#  Les systèmes de résum
#  é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement
#  en fonction des besoins de l'utilisateur.,
#  Un exemple de problème de résumé est le résumé de documents, qui tente de produire
#  automatiquement un résumé à partir d'un document donné.,
#  Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
# ...

# %%
sentence_scores = {}

for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
sentence_scores
# Out:
# {Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de
#  résumé.: 3.5625,
#  Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
#  isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.).: 4.9375,
#  Le second est le résumé pertinent pour une
#  requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête.: 4.1875,
#  Les systèmes de résum
#  é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement
#  en fonction des besoins de l'utilisateur.: 3.5,
#  Un exemple de problème de résumé est le résumé de documents, qui tente de produire
#  automatiquement un résumé à partir d'un document donné.: 5.0625,
#  Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
# ...

# %%
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens)*0.4)
select_length
# Out:
# 6

# %%
summary = nlargest(select_length, sentence_scores, key=sentence_scores.get)

# %%
summary
# Out:
# [Un exemple de problème de résumé est le résumé de documents, qui tente de produire
#  automatiquement un résumé à partir d'un document donné.,
#  Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
#  isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.).,
#  I
#  maginez un système qui rassemble automatiquement des articles d'actualité sur un sujet donné (à partir du Web) et représent
#  e de manière concise les dernières informations sous forme de résumé.,
#  Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
#  ument source, tandis que d'autres peuvent utiliser plusieurs documents sources (par exemple, un ensemble d'articles sur le
#  même sujet).,
#  Le second est le résumé pertinent pour une
#  requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête.,
#  Le résumé d'une collection d'images est un autre exemp
# ...

# %%
summary
# Out:
# [Un exemple de problème de résumé est le résumé de documents, qui tente de produire
#  automatiquement un résumé à partir d'un document donné.,
#  Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
#  isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.).,
#  I
#  maginez un système qui rassemble automatiquement des articles d'actualité sur un sujet donné (à partir du Web) et représent
#  e de manière concise les dernières informations sous forme de résumé.,
#  Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
#  ument source, tandis que d'autres peuvent utiliser plusieurs documents sources (par exemple, un ensemble d'articles sur le
#  même sujet).,
#  Le second est le résumé pertinent pour une
#  requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête.,
#  Le résumé d'une collection d'images est un autre exemp
# ...

# %%
sentence_scores
# Out:
# {Il existe essentiellement deux types de tâches de résumé extractif en fonction de ce sur quoi se concentre le programme de
#  résumé.: 3.5625,
#  Le premier est le résumé générique, qui vise à obtenir un résumé générique ou abstrait de la collection (qu'il s'ag
#  isse de documents, d'ensembles d'images, de vidéos, d'articles de presse, etc.).: 4.9375,
#  Le second est le résumé pertinent pour une
#  requête, parfois appelé résumé basé sur une requête, qui résume des objets spécifiques à une requête.: 4.1875,
#  Les systèmes de résum
#  é sont capables de créer à la fois des résumés textuels pertinents pour une requête et des résumés générés automatiquement
#  en fonction des besoins de l'utilisateur.: 3.5,
#  Un exemple de problème de résumé est le résumé de documents, qui tente de produire
#  automatiquement un résumé à partir d'un document donné.: 5.0625,
#  Parfois, on peut souhaiter générer un résumé à partir d'un seul doc
# ...

# %%
final_summary = [word.text for word in summary]

# %%
finar
