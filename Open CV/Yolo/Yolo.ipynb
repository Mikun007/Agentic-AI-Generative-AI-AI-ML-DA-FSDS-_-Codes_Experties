# %%
import ultralytics
print(ultralytics.__version__)
print(ultralytics.checks())
# Out:
# Ultralytics 8.4.11  Python-3.13.5 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# Setup complete  (16 CPUs, 15.3 GB RAM, 450.8/780.1 GB disk)
# None

# %%
# !yolo predict model = yolov8n.pt source="https://risucrayon.com/wp-content/uploads/2019/03/Songoku-Super-Saiyan.jpg"
# Out:
# ...
# Ultralytics 8.4.11  Python-3.13.5 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
#
# ...
# image 1/1 D:\Mikun\All Learnings\Data Science PyCharm\Yolo ( Ultralytics )\Songoku-Super-Saiyan.jpg: 352x640 7 persons, 2 bananas, 187.2ms
# Speed: 8.2ms preprocess, 187.2ms inference, 13.6ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to D:\Mikun\All Learnings\Data Science PyCharm\Yolo ( Ultralytics )\runs\detect\predict
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolo26n.pt source="https://risucrayon.com/wp-content/uploads/2019/03/Songoku-Super-Saiyan.jpg"
# Out:
# ...
# Ultralytics 8.4.11  Python-3.13.5 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# Found https://risucrayon.com/wp-content/uploads/2019/03/Songoku-Super-Saiyan.jpg locally at Songoku-Super-Saiyan.jpg
# image 1/1 D:\Mikun\All Learnings\Data Science PyCharm\Yolo ( Ultralytics )\Songoku-Super-Saiyan.jpg: 352x640 6 persons, 100.0ms
# Speed: 3.4ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to D:\Mikun\All Learnings\Data Science PyCharm\Yolo ( Ultralytics )\runs\detect\predict3
#  Learn more at https://docs.ultralytics.com/modes/predict
