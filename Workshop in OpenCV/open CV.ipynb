# %% [markdown]
# # INTRODUCTION TO OPENCV & IMAGE PROCESSING

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.0 MB 417.1 kB/s eta 0:01:33
#     --------------------------------------- 0.5/39.0 MB 417.1 kB/s eta 0:01:33
#     --------------------------------------- 0.5/39.0 MB 417.1 kB/s eta 0:01:33
#     --------------------------------------- 0.8/39.0 MB 415.8 kB/s eta 0:01:32
#     --------------------------------------- 0.8/39.0 MB 415.8 kB/s eta 0:01:32
#     --------------------------------------- 0.8/39.0 MB 415.8 kB/s eta 0:01:32
#     --------------------------------------- 0.8/39.0 MB 415.8 kB/s eta 0:01:32
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\mikun\Downloads\elephant.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (724, 626, 3)

# %% [markdown]
# ## Color chanel for each
# ### Matplotlib --> RGB
# ### OpenCV Chan --> BGR

# %%
plt.imshow(img)
plt.show()

# %%
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
# ...

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
# ...

# %%
fix_img.shape
# Out:
# (724, 626, 3)

# %%
plt.imshow(fix_img)
plt.show()

# %%
img_gray = cv2.imread(r"C:\Users\mikun\Downloads\elephant.jpg", cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (724, 626)

# %%
img_gray
# Out:
# array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 254, ..., 254, 254, 254],
#        [255, 255, 254, ..., 254, 254, 254],
#        [255, 255, 254, ..., 254, 255, 255]], dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)
plt.show()

# %%
plt.imshow(img_gray, cmap="gray")
plt.show()

# %%
plt.imshow(img_gray, cmap="magma")
plt.show()

# %%
plt.imshow(img_gray, cmap="summer")
plt.show()

# %%
plt.imshow(img_gray, cmap="Accent")
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(fix_img)
plt.show()

# %%
fix_img.shape
# Out:
# (724, 626, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [255, 255, 255],
# ...

# %%
plt.imshow(fix_img_2)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 0)
plt.imshow(img3)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 1)
plt.imshow(img3)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 3)
plt.imshow(img3)
plt.show()

# %%
cv2.imwrite("new genai image.jpg", img3)
# Out:
# True
