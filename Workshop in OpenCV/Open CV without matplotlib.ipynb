# %% [markdown]
# # Without using matplotlib we work image with open cv

# %%
import cv2

myimg = img = cv2.imread(r"C:\Users\mikun\Downloads\me3.png")

# %%
type(myimg)
# Out:
# NoneType

# %%
type(myimg)
# Out:
# numpy.ndarray

# %%
import cv2

myimg = img = cv2.imread(r"C:\Users\mikun\Downloads\me3.png")

cv2.imshow('my image', myimg)
cv2.waitKey() # till the time user don't closed it will remain open
# Out:
# -1

# %%
import cv2

myimg = img = cv2.imread(r"C:\Users\mikun\Downloads\me3.png")

while True:
    cv2.imshow("my image", myimg)
    
    if cv2.waitKey(1) & 0xff == 27:
        break
    
cv2.destroyAllWindows()
