# %% [markdown]
# ### Package = Library ( Collection of module )
# ### Module = Collection of function
# ### Function = Collection of statement
# * inbuild func
# * user define function

# %% [markdown]
# # Math Module

# %%
name1 = 'fine'
name1 = name1[1:]
name1 = 'd' + name1
name1
# Out:
# 'dine'

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  keyword
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/keyword.html
#
#     The following documentation is automatically generated from the Python
# ...

# %% [markdown]
# ### Swapping vairalbe in python

# %%
a, b = 5, 6
print(a, b)
# Out:
# 5 6

# %%
a, b = b, a

# %%
print(a, b)
# Out:
# 6 5

# %%
a2 = 5
b2 = 6

# %% [markdown]
# `Using addition and subtraction`

# %%
a2 = a2 + b2
b2 = a2 - b2
a2 = a2 - b2
print(a2, b2)
# Out:
# 6 5

# %% [markdown]
# ### Import math function

# %%
import math

# %%
x = math.sqrt(25)
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %% [markdown]
# ### `floor and ceil`

# %%
print(math.floor(2.9))
print(math.ceil(2.9))
# Out:
# 2
# 3

# %%
print(math.pow(3,4))
# Out:
# 81.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
import math as m  # This is called allias

m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
from math import sqrt, pow

pow(25, 3)
# Out:
# 15625.0

# %% [markdown]
# ### Run python code using cli (command line interpreter)
# * Open the text file
# * write few line code & sae to .py file
# * cmd - cd desktop -- python test.py

# %% [markdown]
# ## Input()
# https://docs.python.org/3.12/tutorial/
