# %%
# !pip install -U langgraph
# Out:
# Requirement already satisfied: langgraph in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (1.0.10)
# Collecting langgraph
#   Downloading langgraph-1.1.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: langchain-core>=0.1 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph) (1.2.17)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: pydantic>=2.7.4 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph) (2.12.4)
# Requirement already satisfied: xxhash>=3.5.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: anyio in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.0)
# Requirement already satisfied: certifi in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (0.6.8)
# Requirement already satisfied: packaging>=23.2.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\Mikun\All Learnings\Data Science PyCharm\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Downloading langgraph-1.1.1-py3-none-any.whl (167 kB)
# Installing collected packages: langgraph
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.0.10
#     Uninstalling langgraph-1.0.10:
#       Successfully uninstalled langgraph-1.0.10
# Successfully installed langgraph-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 1.2.10 requires langgraph<1.1.0,>=1.0.8, but you have langgraph 1.1.1 which is incompatible.

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display

# %%
class MyState(TypedDict):
    message: str

# Define the start node
def start_node(state: MyState) -> MyState:
    print("Start node received:", state["message"])
    # Process or pass the message to the end node
    return {"message": state["message"] + " -> processed by start"}

# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# Build the graph
builder = StateGraph(MyState)


# Define the end node
#def end_node(state: MyState) -> MyState:
#    print("End node received:", state["message"])
#    return state

# %%
builder

# %%
builder.add_node("start", start_node)
builder.add_node("end", end_node)

# %%
builder.set_entry_point("start")
builder.add_edge("start", "end")
builder.add_edge("end", END) # END is a special marker for graph completion

# %%
#compile the graph
graph = builder.compile()

# Run the graph
result = graph.invoke({"message": "Explain about LangGraph"})
print("Final result:", result["message"])
# Out:
# Start node received: Explain about LangGraph
# End node received: Explain about LangGraph -> processed by start
# Final result: Explain about LangGraph -> processed by start
