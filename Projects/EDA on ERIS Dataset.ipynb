# %%
import numpy as np # linear algebra
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Iris data set
iris = pd.read_csv(r"D:\Mikun\All Learnings\EDA learnings\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# head display
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# drop the id column as it already has one
iris.drop('Id',axis=1, inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Missing value check

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### This data set has three varities of Iris Plant.
#
# **Bar Plot:** Here the frequency of the observation is plotted. In this case we are plotting the frequency of the three species in the Iris Dataset

# %%
sns.countplot(x = iris['Species'], hue=iris['Species'])
plt.show()

# %% [markdown]
# We can see that there are 50 samples each of all the Iris Species in the data set.
#
# **Joint Plot:** Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
fig

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.jointplot(x=iris['SepalLengthCm'], y=iris['SepalWidthCm'], kind='reg');

# %%
fig = sns.jointplot(x=iris['SepalLengthCm'], y=iris['SepalWidthCm'], kind='hex')

# %% [markdown]
# #### FacetGrid Plot

# %%
sns.FacetGrid(iris, hue='Species', height=5)\
.map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm')\
.add_legend();

# %% [markdown]
# ##### From above data set we can clearly see that **Iris-Setosa's** width is bigger than it's length and **Iris-Virginica** Length is bit bigger than it's width but **Iris-Versicolor's** length and width is similar.

# %% [markdown]
# ### BoxPlot or Whisker Plot

# %% [markdown]
# **Boxplot or Whisker plot:**
# Box plot was first introduced in year 1969 by Mathematician John Turkey. Box plot give a statical summary of the features being plotted.
# * Top line represent the max value.
# * Top edge of box is theird Quartile.
# * middle edge represents the median.
# * Bottom edge represents the first quartile value.
# * The bottom most line represent the minimum value of the feature.
# * The height of the box is called as interquartile range.
# * The black dots on the plot represent the outlier values in the data.

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.boxplot(x='Species', y='PetalLengthCm', data=iris,
                  order=['Iris-virginica', 'Iris-versicolor', 'Iris-setosa'],
                  linewidth=2.5, orient='v', dodge=False, hue='Species'
                 );
plt.show()

# %%
iris.boxplot(by='Species', figsize=(12, 6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %% [markdown]
# #### From Above
#
# * **Iris-setosa:**
#     - The Petal Length of this species lower compare to the Sepal length.
#     - The Petal Width lower compare to the Sepal Width.
# * **Iris-Versicolor:**
#     - The Petal Length of this species is lower compare to the Sepal Length.
#     - The Petal Width is lower to the Sepal Width.
# * **Iris-Virginica:**
#     - The Petal Length of this species is lower compare to the Sepal Length.
#     - The Petal Width is lower to the Sepal Width.
#
#
# But if you see overall from this graph you can see that size of each flower follow this pattern **Iris-Setosa < Iris-Versicolor < Iris-virginica**

# %% [markdown]
# ### Strip Plot

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.stripplot(x='Species', y='SepalLengthCm',
                    data=iris, jitter=True,
                    edgecolor='gray', size=8,
                    palette='winter', orient='v'
                   );

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.boxplot(x='Species', y='SepalLengthCm', data=iris, hue='Species')
ax = sns.stripplot(x='Species', y='SepalLengthCm',data=iris,
                   jitter=True, edgecolor='gray', hue='Species')
plt.show()

# %%
# set-up
fig, ax = plt.subplots(figsize=(10, 6))

# palette maps each species to a color
palette = {
    'Iris-setosa': 'green',
    'Iris-versicolor': 'red',
    'Iris-virginica': 'yellow'
}

# boxplot with palette
ax = sns.boxplot(x='Species', y='PetalLengthCm', data=iris, ax=ax, palette=palette)

# overlay stripplot
ax = sns.stripplot(x='Species', y='PetalLengthCm', data=iris,
              jitter=True, hue='Species', dodge=False, ax=ax)


plt.show()

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# **Violin Plot:** It is used to visualize the distribution of data and its probability distribution.
# * This is a combination of a BoxPlot and DensityPlot that is rotated and placed on each side, to show the distribution shape of the data.
# * The thick black bar is the center represents the interquartile range, the thin black line extended from it represents the 95% confidence intervals, and the white dot is the median. Box plots are limited in their display of the data, as their visual simplicity tends to hide significant details about how values in the data are distributed

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.violinplot(x='Species', y='SepalLengthCm', data=iris, hue='Species')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
ax1 = sns.violinplot(x='Species', y='PetalLengthCm',
                     data=iris,
                     hue='Species',
                     ax=ax[0, 0])

ax2 = sns.violinplot(x='Species', y='PetalWidthCm',
                     data=iris,
                     hue='Species',
                     ax=ax[0,1])

ax3 = sns.violinplot(x='Species', y='SepalLengthCm',
                     data=iris,
                     hue='Species',
                     ax=ax[1,0])
ax4 = sns.violinplot(x='Species', y='SepalWidthCm',
                     data=iris,
                     hue='Species',
                     ax=ax[1,1])

plt.show()

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# **Pair Plot:** A "Pairs Plot" is is also known as scatterplot, in which one variable in the same data row is mathed with another variable's value, like this: pairs plots are just elaborations on this, showing all variables paired with all the other variables.

# %%
sns.pairplot(data=iris, kind='scatter');

# %%
sns.pairplot(data=iris, hue='Species');

# %% [markdown]
# ## Heat Map:

# %% [markdown]
# **Heat Map** is used to find out the correlation between different features in the dataset. High positive or negative values shows that the features have high correlation. This helps us to select the parameters for machine learning.

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.corr(numeric_only=True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
fig, ax = plt.subplots(figsize=(10, 7))

ax = sns.heatmap(iris.corr(numeric_only=True), annot=True,
                 cmap='cubehelix', linewidths=0.5)

ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
ax.set_yticklabels(ax.get_yticklabels(), rotation=360)

plt.title("Corelation Heat Map of Iris Dataset")
plt.show()

# %% [markdown]
# ## Distribution Plot

# %% [markdown]
# **Distribution plot:** The distribution plot is suitable for comparing range and distribution for groups of numerical data. Data is plotted as value points along an axis. You can chose to display only value points to see the distribution of values, a bounding box to see the range of values, or a combination of both as shown here. The distribution plot is not relevant for deatailed analysis of the data as it deals with a summary of the data distribution.

# %%
iris.hist(edgecolor='black', linewidth=1.2);

# %% [markdown]
# ## Swarm Plot

# %% [markdown]
# **Swarm Plot** looks a bit like a friendly warm of bees buzzing about their hive. More importantly each data point is clearly visible and no data are obscured by overplotting. A beeswarm plot improves upon the random jittering approach to move data points the minimum distance away from one another to avoid overlays. The result is a plot where you can see each distinct data point, like shown in below plot.

# %%
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.swarmplot(x='Species', y='PetalLengthCm', data=iris, hue='Species')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax = sns.violinplot(x='Species', y='PetalLengthCm', data=iris, inner=None, hue='Species')
ax = sns.swarmplot(x="Species", y='PetalLengthCm', data=iris,
                   color='white', edgecolor='black')
plt.show()

# %% [markdown]
# ## LM Plot

# %%
f=sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=iris)
plt.show()

# %% [markdown]
# ## FacetGrid

# %%
sns.FacetGrid(iris, hue="Species", height=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
plt.show();

# %% [markdown]
# ## Factor Plot/ Point Plot

# %%
sns.pointplot(x='Species', y='SepalLengthCm', data=iris)
plt.show()

# %% [markdown]
# # Boxen Plot

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.boxenplot(x='Species', y='SepalLengthCm', data=iris, hue='Species')
plt.show()

# %% [markdown]
# ## KDE Plot

# %%
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.
sub = iris[iris['Species'] == 'Iris-setosa']
sns.kdeplot(data=sub, x='SepalLengthCm', y='SepalWidthCm',
            palette='plasma', shade=True, shade_lowest=False)
plt.title("Iris-Setosa")
plt.xlabel("Sepal Length Cm")
plt.ylabel("Sepal Width Cm")
plt.show()

# %% [markdown]
# ## Dashboard

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize= (15, 15))

k1 = sns.boxplot(x="Species", y="PetalLengthCm", data=iris,
                 ax=axes[0, 0], hue="Species")

k2 = sns.violinplot(x="Species", y="PetalLengthCm", data=iris,
                    ax=axes[0,1], hue="Species")

k3 = sns.stripplot(x='Species', y='PetalLengthCm',
                   data=iris, ax=axes[1, 0], hue="Species")

axes[1, 1].hist(iris.PetalLengthCm, bins=100)
plt.show()

# %% [markdown]
# In the dashboard we have shown how to create multiple plots to foam a dashboard using python. In this plot we have demonstrated how to plot seaborn and matplotlib plots on the same dashboard.

# %% [markdown]
# ## Stacked Histogram

# %%
iris['Species'] = iris['Species'].astype('category')
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
list1 = []
mylabels = []

for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species==gen].SepalLengthCm)
    mylabels.append(gen)

h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# With Stacked Histogram we can see the distribution of sepal length of different species together. This shows us the range of Sepal Length for the three different Species of Iris Flower.
#
# **Area Plot:** Area plot gives us a visual representation of various dimensions of Iris flower and their range in dataset.

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
               alpha=0.4,figsize=(12, 6));
plt.show()

# %% [markdown]
# **DistPlot** It helps us to look at the distribution of a single variable. KDE shows the density of the distribution

# %%
sns.distplot(iris["SepalLengthCm"], kde=True, bins=20);
plt.show()
